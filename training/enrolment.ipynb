# %%
import pandas as pd

# %%
df = pd.read_csv('enrolment_age.csv')

# %%
df['age'].describe()
# Out:
# count    14660.000000
# mean        13.500000
# std          5.766478
# min          4.000000
# 25%          8.750000
# 50%         13.500000
# 75%         18.250000
# max         23.000000
# Name: age, dtype: float64

# %%
df['age'].min()
# Out:
# 4

# %%
df['age'].max()
# Out:
# 23

# %%
pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.6 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.6 kB 325.1 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.6 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 402.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/45.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/45.9 MB 3.3 MB/s eta 0:00:14
#    ---------------------------------------- 0.3/45.9 MB 3.2 MB/s eta 0:00:15
#    ---------------------------------------- 0.4/45.9 MB 3.6 MB/s eta 0:00:13
#     --------------------------------------- 0.6/45.9 MB 3.3 MB/s eta 0:00:14
#     --------------------------------------- 0.8/45.9 MB 3.5 MB/s eta 0:00:14
#     --------------------------------------- 1.0/45.9 MB 3.6 MB/s eta 0:00:13
# ...

# %%
from scipy.stats import uniform

# %%
mini = 12
maxi = 15

# %%
uniform.pdf(mini,maxi)
# Out:
# 0.0

# %%
uniform.mean()
# Out:
# 0.5
