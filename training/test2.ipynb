# %%
import pandas as pd

# %%
df = pd.read_csv('D:/python practice/data file/catalog.csv')

# %%
df
# Out:
#         id     date   time continent_code   country_name country_code  \
# 0       34   3/2/07  Night            NaN  United States           US
# 1       42  3/22/07    NaN            NaN  United States           US
# 2       56   4/6/07    NaN            NaN  United States           US
# 3       59  4/14/07    NaN            NaN         Canada           CA
# 4       61  4/15/07    NaN            NaN  United States           US
# ...    ...      ...    ...            ...            ...          ...
# 1688  7535  12/7/15    NaN            NaN  United States           US
# 1689  7537  2/22/16   0:00            NaN  United States           US
# 1690  7539  2/23/16    NaN            NaN  United States           US
# 1691  7540  2/26/16  21:06            NaN  United States           US
# 1692  7541   3/2/16   8:00            NaN  United States           US
#
#       state/province  population         city/town  distance  ...  \
# ...

# %%
df['date']= pd.to_datetime(df['date'],format="%m/%d/%y")

# %%
df
# Out:
#         id       date   time continent_code   country_name country_code  \
# 0       34 2007-03-02  Night            NaN  United States           US
# 1       42 2007-03-22    NaN            NaN  United States           US
# 2       56 2007-04-06    NaN            NaN  United States           US
# 3       59 2007-04-14    NaN            NaN         Canada           CA
# 4       61 2007-04-15    NaN            NaN  United States           US
# ...    ...        ...    ...            ...            ...          ...
# 1688  7535 2015-12-07    NaN            NaN  United States           US
# 1689  7537 2016-02-22   0:00            NaN  United States           US
# 1690  7539 2016-02-23    NaN            NaN  United States           US
# 1691  7540 2016-02-26  21:06            NaN  United States           US
# 1692  7541 2016-03-02   8:00            NaN  United States           US
#
#       state/province  population         city/town  distance  ...  \
# ...

# %%
# Out:
# <bound method DataFrame.info of         id       date   time continent_code   country_name country_code  \
# 0       34 2007-03-02  Night            NaN  United States           US
# 1       42 2007-03-22    NaN            NaN  United States           US
# 2       56 2007-04-06    NaN            NaN  United States           US
# 3       59 2007-04-14    NaN            NaN         Canada           CA
# 4       61 2007-04-15    NaN            NaN  United States           US
# ...    ...        ...    ...            ...            ...          ...
# 1688  7535 2015-12-07    NaN            NaN  United States           US
# 1689  7537 2016-02-22   0:00            NaN  United States           US
# 1690  7539 2016-02-23    NaN            NaN  United States           US
# 1691  7540 2016-02-26  21:06            NaN  United States           US
# 1692  7541 2016-03-02   8:00            NaN  United States           US
#
#       state/province  population         city/town  distance  ...  \
# ...

# %%
#df['year']= df['date'].dt.year

df['month'] = df['date'].dt.month

# %%
df
# Out:
#         id       date   time continent_code   country_name country_code  \
# 0       34 2007-03-02  Night            NaN  United States           US
# 1       42 2007-03-22    NaN            NaN  United States           US
# 2       56 2007-04-06    NaN            NaN  United States           US
# 3       59 2007-04-14    NaN            NaN         Canada           CA
# 4       61 2007-04-15    NaN            NaN  United States           US
# ...    ...        ...    ...            ...            ...          ...
# 1688  7535 2015-12-07    NaN            NaN  United States           US
# 1689  7537 2016-02-22   0:00            NaN  United States           US
# 1690  7539 2016-02-23    NaN            NaN  United States           US
# 1691  7540 2016-02-26  21:06            NaN  United States           US
# 1692  7541 2016-03-02   8:00            NaN  United States           US
#
#       state/province  population         city/town  distance  ...  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'time', 'continent_code', 'country_name', 'country_code',
#        'state/province', 'population', 'city/town', 'distance',
#        'location_description', 'latitude', 'longitude', 'geolocation',
#        'hazard_type', 'landslide_type', 'landslide_size', 'trigger',
#        'storm_name', 'injuries', 'fatalities', 'source_name', 'source_link',
#        'year', 'month'],
#       dtype='object')

# %%
df = df[['id', 'date', 'year', 'month','time', 'continent_code', 'country_name', 'country_code',
       'state/province', 'population', 'city/town', 'distance',
       'location_description', 'latitude', 'longitude', 'geolocation',
       'hazard_type', 'landslide_type', 'landslide_size', 'trigger',
       'storm_name', 'injuries', 'fatalities', 'source_name', 'source_link'
       ]]

# %%
df
# Out:
#         id       date    year  month   time continent_code   country_name  \
# 0       34 2007-03-02  2007.0    3.0  Night            NaN  United States
# 1       42 2007-03-22  2007.0    3.0    NaN            NaN  United States
# 2       56 2007-04-06  2007.0    4.0    NaN            NaN  United States
# 3       59 2007-04-14  2007.0    4.0    NaN            NaN         Canada
# 4       61 2007-04-15  2007.0    4.0    NaN            NaN  United States
# ...    ...        ...     ...    ...    ...            ...            ...
# 1688  7535 2015-12-07  2015.0   12.0    NaN            NaN  United States
# 1689  7537 2016-02-22  2016.0    2.0   0:00            NaN  United States
# 1690  7539 2016-02-23  2016.0    2.0    NaN            NaN  United States
# 1691  7540 2016-02-26  2016.0    2.0  21:06            NaN  United States
# 1692  7541 2016-03-02  2016.0    3.0   8:00            NaN  United States
#
#      country_code  state/province  population  ...  \
# ...

# %%
df.dropna(subset=['year'])
# Out:
#         id       date    year  month   time continent_code   country_name  \
# 0       34 2007-03-02  2007.0    3.0  Night            NaN  United States
# 1       42 2007-03-22  2007.0    3.0    NaN            NaN  United States
# 2       56 2007-04-06  2007.0    4.0    NaN            NaN  United States
# 3       59 2007-04-14  2007.0    4.0    NaN            NaN         Canada
# 4       61 2007-04-15  2007.0    4.0    NaN            NaN  United States
# ...    ...        ...     ...    ...    ...            ...            ...
# 1688  7535 2015-12-07  2015.0   12.0    NaN            NaN  United States
# 1689  7537 2016-02-22  2016.0    2.0   0:00            NaN  United States
# 1690  7539 2016-02-23  2016.0    2.0    NaN            NaN  United States
# 1691  7540 2016-02-26  2016.0    2.0  21:06            NaN  United States
# 1692  7541 2016-03-02  2016.0    3.0   8:00            NaN  United States
#
#      country_code  state/province  population  ...  \
# ...

# %%
df['year'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df['year'].astype(int)
#
# File c:\Users\New\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6640, in NDFrame.astype(self, dtype, copy, errors)
#    6634     results = [
#    6635         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6636     ]
#    6638 else:
#    6639     # else, only a single dtype is given
# -> 6640     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6641     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6642     return res.__finalize__(self, method="astype")
#
# File c:\Users\New\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...
